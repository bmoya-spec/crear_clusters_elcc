# %%
import pandas as pd
import os
#cwd = os.getcwd()
#print(cwd)
# Out:
# C:\Users\bmoya\Codigos\Herramientas\Crear clusters

# %%
gen = pd.read_csv('gen.csv',encoding = "utf-8")
gen = gen[gen.type == 'ror']
hydro = pd.read_csv('hydro.csv',encoding = "utf-8")
inflows = pd.read_csv('inflows.csv',encoding = "utf-8")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18588/2621730989.py in <module>
# ----> 1 gen = pd.read_csv('gen.csv',encoding = "utf-8")
#       2 gen = gen[gen.type == 'ror']
#       3 hydro = pd.read_csv('hydro.csv',encoding = "utf-8")
#       4 inflows = pd.read_csv('inflows.csv',encoding = "utf-8")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      67         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
#      68         try:
# ---> 69             self._reader = parsers.TextReader(self.handles.handle, **kwds)
#      70         except Exception:
#      71             self.handles.close()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xba in position 55685: invalid start byte

# %%
gen = gen[(gen.type == 'ror') & (gen.subsystem == "Norte")]

# %%
gen
# Out:
#               name  capacity     IFOR category type subsystem
# 98        CAVANCHA       2.6  0.00532    hydro  ror     Norte
# 215     RIO_HUASCO       5.1  0.00131    hydro  ror     Norte
# 599  ALTO_HOSPICIO       1.1  0.00645    hydro  ror     Norte
# 639     CHAPIQUINA      10.8  0.00725    hydro  ror     Norte
# 692     EL_TORO_N2       1.1  0.00895    hydro  ror     Norte
# 796     SANTA_ROSA       1.3  0.00641    hydro  ror     Norte

# %%
hydro
# Out:
#            name  vmax  vmin  rend  filtrated  turbined spilled
# 0       ABANICO   0.0     0  1.20        0.0    ANTUCO  ANTUCO
# 1        AILLIN   0.0     0  1.00        0.0         0       0
# 2      ALFALFAL   0.0     0  5.94        0.0         0       0
# 3    ALFALFAL 2   0.0     0  9.80        0.0         0       0
# 4       ALLIPEN   0.0     0  1.00        0.0         0       0
# ..          ...   ...   ...   ...        ...       ...     ...
# 178    TRANQUIL   0.0     0  1.00        0.0         0       0
# 179      TRUFUL   0.0     0  1.00        0.0         0       0
# 180      Trupan   0.0     0  1.00        0.0         0       0
# 181     TUCAPEL   0.0     0  1.00        0.0  EL_DIUTO  LAJA_I
# 182      VOLCAN   0.0     0  1.00        0.0         0       0
#
# [183 rows x 7 columns]

# %%
gen = gen.drop(columns = ["IFOR","category","type","subsystem"])

hydro = hydro.drop(columns = ["vmax","vmin","filtrated","turbined","spilled"])

# %%
inflows
# Out:
#       week  hidrology  LOS_MORROS  MAITENES  PUNTILLA  ALFALFAL  VOLCAN  \
# 0        1       1961        3.15     14.92     15.50     42.60   12.20
# 1        2       1961        2.53     14.49     14.06     41.43   11.75
# 2        3       1961        2.53     14.49     14.68     37.37   11.75
# 3        4       1961        2.53     14.49     17.09     24.40   11.75
# 4        5       1961        1.74     13.80     16.39     31.41   11.75
# ...    ...        ...         ...       ...       ...       ...     ...
# 2683    44       2016        2.83     12.45     15.65     22.17   11.75
# 2684    45       2016        2.80     15.19     14.08     28.94   11.75
# 2685    46       2016        2.73     15.19     14.55     28.04   11.75
# 2686    47       2016        2.72     15.19     13.89     33.54   11.75
# 2687    48       2016        2.68     15.19     14.25     32.11   11.75
#
#       QUELTEHUES  SAUZALITO  SAUZAL  ...  PMGD CH EL ATAJO  PMGD HP EL BRINCO  \
# 0          45.98       9.63   61.61  ...             0.726              0.165
# 1          44.25       9.55   61.15  ...             0.726              0.330
# 2          44.25       9.55   61.15  ...             0.726              0.210
# 3          44.25       9.55   61.15  ...             0.726              0.240
# 4          44.25       9.83   62.93  ...             0.726              0.180
# ...          ...        ...     ...  ...               ...                ...
# 2683       44.27      10.56   67.60  ...             0.726              0.160
# 2684       44.27      10.52   67.32  ...             0.726              0.180
# 2685       44.27      10.52   67.32  ...             0.726              0.180
# 2686       44.27      10.52   67.32  ...             0.726              0.180
# 2687       44.27      10.52   67.32  ...             0.726              0.180
#
#       EL_PINAR  JUNCALITO  ALTO_LA_VINA  LOS_COLONOS  PALACIOS  \
# 0        10.30          1             1            1         1
# 1        20.60          1             1            1         1
# 2        13.24          1             1            1         1
# 3        15.38          1             1            1         1
# 4         1.84          1             1            1         1
# ...        ...        ...           ...          ...       ...
# 2683      6.90          1             1            1         1
# 2684      6.45          1             1            1         1
# 2685      6.45          1             1            1         1
# 2686      6.45          1             1            1         1
# 2687      6.45          1             1            1         1
#
#       HP PANGUIPULLI  QUILLAILEO  CORRALES
# 0                  1           1         1
# 1                  1           1         1
# 2                  1           1         1
# 3                  1           1         1
# 4                  1           1         1
# ...              ...         ...       ...
# 2683               1           1         1
# 2684               1           1         1
# 2685               1           1         1
# 2686               1           1         1
# 2687               1           1         1
#
# [2688 rows x 185 columns]

# %%
inflows = inflows.melt(id_vars = ["week","hidrology"], var_name = "Central", value_name = "Afluente")

# %%
inflows
# Out:
#         week  hidrology     Central  Afluente
# 0          1       1961  LOS_MORROS      3.15
# 1          2       1961  LOS_MORROS      2.53
# 2          3       1961  LOS_MORROS      2.53
# 3          4       1961  LOS_MORROS      2.53
# 4          5       1961  LOS_MORROS      1.74
# ...      ...        ...         ...       ...
# 491899    44       2016    CORRALES      1.00
# 491900    45       2016    CORRALES      1.00
# 491901    46       2016    CORRALES      1.00
# 491902    47       2016    CORRALES      1.00
# 491903    48       2016    CORRALES      1.00
#
# [491904 rows x 4 columns]

# %%
df = inflows.merge(gen, left_on = "Central",right_on = "name")

# %%
df = df.merge(hydro, left_on = "Central", right_on = "name")
df
# Out:
#        week  hidrology     Central  Afluente      name_x  capacity  \
# 0         1       1961  RIO_HUASCO      1.48  RIO_HUASCO       5.1
# 1         2       1961  RIO_HUASCO      1.13  RIO_HUASCO       5.1
# 2         3       1961  RIO_HUASCO      1.13  RIO_HUASCO       5.1
# 3         4       1961  RIO_HUASCO      1.13  RIO_HUASCO       5.1
# 4         5       1961  RIO_HUASCO      1.25  RIO_HUASCO       5.1
# ...     ...        ...         ...       ...         ...       ...
# 16123    44       2016  SANTA_ROSA      0.50  SANTA_ROSA       1.3
# 16124    45       2016  SANTA_ROSA      0.50  SANTA_ROSA       1.3
# 16125    46       2016  SANTA_ROSA      0.50  SANTA_ROSA       1.3
# 16126    47       2016  SANTA_ROSA      0.50  SANTA_ROSA       1.3
# 16127    48       2016  SANTA_ROSA      0.50  SANTA_ROSA       1.3
#
#            name_y  rend
# 0      RIO_HUASCO   1.0
# 1      RIO_HUASCO   1.0
# 2      RIO_HUASCO   1.0
# 3      RIO_HUASCO   1.0
# 4      RIO_HUASCO   1.0
# ...           ...   ...
# 16123  SANTA_ROSA   1.0
# 16124  SANTA_ROSA   1.0
# 16125  SANTA_ROSA   1.0
# 16126  SANTA_ROSA   1.0
# 16127  SANTA_ROSA   1.0
#
# [16128 rows x 8 columns]

# %%
df = df.drop(columns = ["name_x","name_y"])
df
# Out:
#        week  hidrology     Central  Afluente  capacity  rend
# 0         1       1961  RIO_HUASCO      1.48       5.1   1.0
# 1         2       1961  RIO_HUASCO      1.13       5.1   1.0
# 2         3       1961  RIO_HUASCO      1.13       5.1   1.0
# 3         4       1961  RIO_HUASCO      1.13       5.1   1.0
# 4         5       1961  RIO_HUASCO      1.25       5.1   1.0
# ...     ...        ...         ...       ...       ...   ...
# 16123    44       2016  SANTA_ROSA      0.50       1.3   1.0
# 16124    45       2016  SANTA_ROSA      0.50       1.3   1.0
# 16125    46       2016  SANTA_ROSA      0.50       1.3   1.0
# 16126    47       2016  SANTA_ROSA      0.50       1.3   1.0
# 16127    48       2016  SANTA_ROSA      0.50       1.3   1.0
#
# [16128 rows x 6 columns]

# %%
df['P_out'] = df.apply(lambda x: min(1,x['Afluente']*x['rend']/x['capacity']), axis = 1)
df = df.drop(columns = ['Afluente','capacity','rend'])
df
# Out:
#        week  hidrology     Central     P_out
# 0         1       1961  RIO_HUASCO  0.290196
# 1         2       1961  RIO_HUASCO  0.221569
# 2         3       1961  RIO_HUASCO  0.221569
# 3         4       1961  RIO_HUASCO  0.221569
# 4         5       1961  RIO_HUASCO  0.245098
# ...     ...        ...         ...       ...
# 16123    44       2016  SANTA_ROSA  0.384615
# 16124    45       2016  SANTA_ROSA  0.384615
# 16125    46       2016  SANTA_ROSA  0.384615
# 16126    47       2016  SANTA_ROSA  0.384615
# 16127    48       2016  SANTA_ROSA  0.384615
#
# [16128 rows x 4 columns]

# %%
df2 = df.pivot_table(index=['week','hidrology'], columns = 'Central',values = 'P_out').reset_index()
df2
# Out:
# Central  week  hidrology  ALTO_HOSPICIO  CAVANCHA  CHAPIQUINA  EL_TORO_N2  \
# 0           1       1961            1.0  0.692308    0.453704    0.818182
# 1           1       1962            1.0  0.692308    0.453704    0.818182
# 2           1       1963            1.0  0.692308    0.453704    0.818182
# 3           1       1964            1.0  0.692308    0.453704    0.818182
# 4           1       1965            1.0  0.692308    0.453704    0.818182
# ...       ...        ...            ...       ...         ...         ...
# 2683       48       2012            1.0  0.692308    0.453704    0.818182
# 2684       48       2013            1.0  0.692308    0.453704    0.818182
# 2685       48       2014            1.0  0.692308    0.453704    0.818182
# 2686       48       2015            1.0  0.692308    0.453704    0.818182
# 2687       48       2016            1.0  0.692308    0.453704    0.818182
#
# Central  RIO_HUASCO  SANTA_ROSA
# 0          0.290196    0.384615
# 1          0.000000    0.384615
# 2          0.000000    0.384615
# 3          0.219608    0.384615
# 4          0.262745    0.384615
# ...             ...         ...
# 2683       0.231373    0.384615
# 2684       0.162745    0.384615
# 2685       0.072549    0.384615
# 2686       0.227451    0.384615
# 2687       0.294118    0.384615
#
# [2688 rows x 8 columns]

# %%
df2.to_csv('inflows_normalized_N.csv', index=False)
